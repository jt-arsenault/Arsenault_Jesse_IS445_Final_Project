# %% [markdown]
# # Visualizations for the General Public

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 1. Read Dataset

# %%
emissions_df = pd.read_csv('./SupplyChainGHGEmissionFactors_v1.2_NAICS_CO2e_USD2021.csv')

# %% [markdown]
# ## 2. Get NAICS Codes by Sector (first digit)

# %%
regex_1 = '^1.*$'
regex_2 = '^2.*$'
regex_3 = '^3.*$'
regex_4 = '^4.*$'
regex_5 = '^5.*$'
regex_6 = '^6.*$'
regex_7 = '^7.*$'
regex_8 = '^8.*$'
regex_9 = '^9.*$'

strings = emissions_df["2017 NAICS Code"].astype("string")

grouped_1 = strings.str.findall(regex_1)
grouped_2 = strings.str.findall(regex_2)
grouped_3 = strings.str.findall(regex_3)
grouped_4 = strings.str.findall(regex_4)
grouped_5 = strings.str.findall(regex_5)
grouped_6 = strings.str.findall(regex_6)
grouped_7 = strings.str.findall(regex_7)
grouped_8 = strings.str.findall(regex_8)
grouped_9 = strings.str.findall(regex_9)

# Agricultural (11) 
agriculture = []
for item in grouped_1:
    if item != []:
        agriculture.append(item)

# Mining, Utilities, Construction (21, 22, 23)
mining = []
for item in grouped_2:
    if item != []:
        mining.append(item)
        
# Manufacturing (31, 32, 33)
manuf = []
for item in grouped_3:
    if item != []:
        manuf.append(item)
        
# Trade (42, 44, 45, 48, 49)
trade = []
for item in grouped_4:
    if item != []:
        trade.append(item)
        
# Finance and Services (51, 52, 53, 54, 55, 56)
finserv = []
for item in grouped_5:
    if item != []:
        finserv.append(item)
        
# Social Services (Education, Health Care) (61, 62)
social = []
for item in grouped_6:
    if item != []:
        social.append(item)
        
# Arts and Food Services (71, 72)
arts = []
for item in grouped_7:
    if item != []:
        arts.append(item)
        
# Other except Public Administration (81)
other = []
for item in grouped_8:
    if item != []:
        other.append(item)
        
# Public Administration
public = []
for item in grouped_9:
    if item != []:
        public.append(item)

# %% [markdown]
# ## Set up Data for Plotting

# %% [markdown]
# ### Averages and Sector-Specific Data

# %%
naics_categories = ["Agriculture (" + str(len(agriculture)) + ")", 
                    "Energy/Construction (" + str(len(mining)) + ")", 
                    "Manufacturing (" + str(len(manuf)) + ")", 
                    "Trade (" + str(len(trade)) + ")",
                    "Business Services (" + str(len(finserv)) + ")",
                    "Social Services (" + str(len(social)) + ")",
                    "Arts (" + str(len(arts)) + ")",
                    "Other (" + str(len(other)) + ")"]

# Allows us to use loc to extract each group
sizes = [len(agriculture),len(mining),len(manuf),len(trade),len(finserv),len(social),len(arts),len(other)]

distance = 0
# 1
df_agr = emissions_df.loc[0:sizes[0]-1]
agr_mean = df_agr["Supply Chain Emission Factors with Margins"].mean()
agr_std = df_agr["Supply Chain Emission Factors with Margins"].std()
distance += sizes[0]

# 2
df_min = emissions_df.loc[distance:(distance + sizes[1]-1)]
min_mean = df_min["Supply Chain Emission Factors with Margins"].mean()
min_std = df_min["Supply Chain Emission Factors with Margins"].std()
distance += sizes[1]

# 3
df_mfc = emissions_df.loc[distance:(distance + sizes[2]-1)]
mfc_mean = df_mfc["Supply Chain Emission Factors with Margins"].mean()
mfc_std = df_mfc["Supply Chain Emission Factors with Margins"].std()
distance += sizes[2]

#4
df_tra = emissions_df.loc[distance:(distance + sizes[3]-1)]
tra_mean = df_tra["Supply Chain Emission Factors with Margins"].mean()
tra_std = df_tra["Supply Chain Emission Factors with Margins"].std()
distance += sizes[3]

# 5
df_ser = emissions_df.loc[distance:(distance + sizes[4]-1)]
ser_mean = df_ser["Supply Chain Emission Factors with Margins"].mean()
ser_std = df_ser["Supply Chain Emission Factors with Margins"].std()
distance += sizes[4]

# 6
df_soc = emissions_df.loc[distance:(distance + sizes[5]-1)]
soc_mean = df_soc["Supply Chain Emission Factors with Margins"].mean()
soc_std = df_soc["Supply Chain Emission Factors with Margins"].std()
distance += sizes[5]

# 7
df_art = emissions_df.loc[distance:(distance + sizes[6]-1)]
art_mean = df_art["Supply Chain Emission Factors with Margins"].mean()
art_std = df_art["Supply Chain Emission Factors with Margins"].std()
distance += sizes[6]

# 8
df_oth = emissions_df.loc[distance:(distance + sizes[7]-1)]
oth_mean = df_oth["Supply Chain Emission Factors with Margins"].mean()
oth_std = df_oth["Supply Chain Emission Factors with Margins"].std()

sector_series = [df_agr["Supply Chain Emission Factors with Margins"],
                 df_min["Supply Chain Emission Factors with Margins"],
                 df_mfc["Supply Chain Emission Factors with Margins"],
                 df_tra["Supply Chain Emission Factors with Margins"],
                 df_ser["Supply Chain Emission Factors with Margins"],
                 df_soc["Supply Chain Emission Factors with Margins"],
                 df_art["Supply Chain Emission Factors with Margins"],
                 df_oth["Supply Chain Emission Factors with Margins"]]
means = [agr_mean, min_mean, mfc_mean, tra_mean, ser_mean, soc_mean, art_mean, oth_mean]
std_array = [agr_std, min_std, mfc_std, tra_std, ser_std, soc_std, art_std, oth_std]

# %% [markdown]
# ### High Emitters, Broadest Categories

# %%
### High Emitters (Agriculture)
regex_1 = '^1.*$'
regex_2 = '^2.*$'
regex_3 = '^3.*$'
regex_4 = '^4.*$'
regex_5 = '^5.*$'
regex_6 = '^6.*$'
regex_7 = '^7.*$'
regex_8 = '^8.*$'
regex_9 = '^9.*$'

strings = emissions_df["2017 NAICS Code"].astype("string")

grouped_1 = strings.str.findall(regex_1)
grouped_2 = strings.str.findall(regex_2)
grouped_3 = strings.str.findall(regex_3)
grouped_4 = strings.str.findall(regex_4)
grouped_5 = strings.str.findall(regex_5)
grouped_6 = strings.str.findall(regex_6)
grouped_7 = strings.str.findall(regex_7)
grouped_8 = strings.str.findall(regex_8)
grouped_9 = strings.str.findall(regex_9)

# Agricultural (11) 
agriculture = []
for item in grouped_1:
    if item != []:
        agriculture.append(item)

# Mining, Utilities, Construction (21, 22, 23)
mining = []
for item in grouped_2:
    if item != []:
        mining.append(item)
        
# Manufacturing (31, 32, 33)
manuf = []
for item in grouped_3:
    if item != []:
        manuf.append(item)
        
# Trade (42, 44, 45, 48, 49)
trade = []
for item in grouped_4:
    if item != []:
        trade.append(item)
        
# Finance and Services (51, 52, 53, 54, 55, 56)
finserv = []
for item in grouped_5:
    if item != []:
        finserv.append(item)
        
# Social Services (Education, Health Care) (61, 62)
social = []
for item in grouped_6:
    if item != []:
        social.append(item)
        
# Arts and Food Services (71, 72)
arts = []
for item in grouped_7:
    if item != []:
        arts.append(item)
        
# Other except Public Administration (81)
other = []
for item in grouped_8:
    if item != []:
        other.append(item)
        
# Public Administration
public = []
for item in grouped_9:
    if item != []:
        public.append(item)

# Obtain and sort agricultural emissions       
agricultural_df = emissions_df.loc[0:len(agriculture)-1]

high_emissions_agr = agricultural_df[agricultural_df["Supply Chain Emission Factors without Margins"] > 1.2]
sorted_emissions_agr = high_emissions_agr.sort_values(by=["Supply Chain Emission Factors without Margins"], ascending=True)
high_emission_factors_agr = sorted_emissions_agr["Supply Chain Emission Factors without Margins"]
high_emission_industries_agr = sorted_emissions_agr["2017 NAICS Title"]

# %% [markdown]
# # Visualizations

# %%
plt.figure(figsize=(24,10))
plt.title("Average Supply Chain Greenhouse Gas Emissions (2021)", size=24)
plt.xlabel("Economic Sector (number of subcategories represented)", size=16, labelpad=15)
plt.ylabel("Average Emission Factor*", size=16, labelpad=15)


box_text = "* \"Emission factor\" represents the expected amount of greenhouse gases released by a business activity.\n    Measured in kilograms of carbon dioxide equivalents produced, divided by the purchaser price in 2021 dollars."
plt.text(0.75,0.8, s=box_text,color="black", backgroundcolor="white",fontsize='xx-large')

plt.bar(naics_categories,means,color="#014421")
plt.show()

# %%
high_emissions = emissions_df[emissions_df["Supply Chain Emission Factors without Margins"] > 1.5]
sorted_emissions = high_emissions.sort_values(by=["Supply Chain Emission Factors without Margins"], ascending=False)

high_emission_factors = sorted_emissions["Supply Chain Emission Factors without Margins"]
high_emission_industries = sorted_emissions["2017 NAICS Title"]

plt.figure(figsize=(24,10))
plt.title("Top 15 Highest Emitting Business Activities (2021)", size=24)
plt.ylabel("Business Activity", size=16, labelpad=15)
plt.xlabel("GHG Emission Factor (kilograms of CO2 divided by cost)", size=16, labelpad=15)

plt.barh(high_emission_industries[0:15],high_emission_factors[0:15], color="#bacd36")
plt.show()

# %%
plt.figure(figsize=(24,10))
plt.title("Agricultural Sectors with the Highest Emissions", size=24)
plt.ylabel("2017 NAICS Description", size=16, labelpad=15)
plt.xlabel("GHG Emission Factor", size=16, labelpad=15)

plt.barh(high_emission_industries_agr,high_emission_factors_agr, color="gold")
plt.show()
